# %%
import json, os

os.chdir("C:\\Users\\ichne\\Documents\\Vue-Y86\\kernel\\test")
res = json.loads(open('run.txt', 'r').read())

# %%
import pprint
pp = pprint.PrettyPrinter(indent=2)

# %%
for i in range(0, len(res)):
    try:
        pp.pprint([i, res[str(i)]['F']['predPC']])
    except:
        continue
# Out:
# [0, '00000000']
# [1, '06000000']
# [2, '0c000000']
# [3, '24000000']
# [4, '2a000000']
# [5, '2c000000']
# [6, '32000000']
# [7, '34000000']
# [8, '3a000000']
# [9, '3c000000']
# [10, '3e000000']
# [11, '44000000']
# [12, '46000000']
# [13, '48000000']
# [14, '4e000000']
# [15, '54000000']
# [16, '56000000']
# [17, '56000000']
# [18, '8b000000']
# [19, '8d000000']
# [20, '93000000']
# [21, '61000000']
# [22, '63000000']
# [23, '69000000']
# [24, '6b000000']
# [25, '6d000000']
# [26, '73000000']
# [27, '75000000']
# [28, '77000000']
# [29, '79000000']
# [30, '3a000000']
# [31, '3c000000']
# [32, '3e000000']
# [33, '44000000']
# [34, '46000000']
# [35, '48000000']
# [36, '4e000000']
# [37, '54000000']
# [38, '56000000']
# [39, '56000000']
# [40, '8b000000']
# [41, '8d000000']
# [42, '93000000']
# [43, '61000000']
# [44, '63000000']
# [45, '69000000']
# [46, '6b000000']
# [47, '6d000000']
# [48, '73000000']
# [49, '75000000']
# [50, '77000000']
# [51, '79000000']
# [52, '3a000000']
# [53, '3c000000']
# [54, '3e000000']
# [55, '44000000']
# [56, '46000000']
# [57, '48000000']
# [58, '4e000000']
# [59, '54000000']
# [60, '56000000']
# [61, '56000000']
# [62, '8b000000']
# [63, '8d000000']
# [64, '93000000']
# [65, '61000000']
# [66, '63000000']
# [67, '69000000']
# [68, '6b000000']
# [69, '6d000000']
# [70, '73000000']
# [71, '75000000']
# [72, '77000000']
# [73, '79000000']
# [74, '3a000000']
# [75, '3c000000']
# [76, '3e000000']
# [77, '44000000']
# [78, '46000000']
# [79, '48000000']
# [80, '4e000000']
# [81, '54000000']
# [82, '56000000']
# [83, '56000000']
# [84, '8b000000']
# [85, '8d000000']
# [86, '93000000']
# [87, '61000000']
# [88, '63000000']
# [89, '69000000']
# [90, '6b000000']
# [91, '6d000000']
# [92, '73000000']
# [93, '75000000']
# [94, '77000000']
# [95, '79000000']
# [96, '3a000000']
# [97, '3c000000']
# [98, '3e000000']
# [99, '44000000']
# [100, '46000000']
# [101, '48000000']
# [102, '4e000000']
# [103, '54000000']
# [104, '56000000']
# [105, '56000000']
# [106, '8b000000']
# [107, '8d000000']
# [108, '93000000']
# [109, '94000000']
# [110, '95000000']
# [111, '95000000']
# [112, '95000000']
# [113, '95000000']
# [114, '21000000']
# [115, '23000000']
# [116, '24000000']
# [117, '2a000000']

# %%
pp.pprint(res['112'])
# Out:
# { 'D': { 'bubble': True,
#          'icode': 1,
#          'ifun': 0,
#          'ins': '00000095: halt',
#          'operation': [],
#          'rA': 15,
#          'rB': 15,
#          'stall': False,
#          'stat': 5,
#          'valC': '--------',
#          'valP': '96000000'},
#   'E': { 'bubble': False,
#          'dstE': 15,
#          'dstM': 15,
#          'icode': 1,
#          'ifun': 0,
#          'ins': '00000095: halt',
#          'operation': [],
#          'srcA': 15,
#          'srcB': 15,
#          'stall': False,
#          'stat': 5,
#          'valA': '--------',
#          'valB': '--------',
#          'valC': '--------'},
#   'F': { 'bubble': False,
#          'ins': '00000095: halt',
#          'operation': [ 'Select current PC 00000095 naturally',
#                         'Halt',
#                         'Select next PC 00000096 naturally'],
#          'predPC': '95000000',
#          'stall': True},
#   'M': { 'Cnd': False,
#          'bubble': False,
#          'dstE': 4,
#          'dstM': 15,
#          'icode': 9,
#          'ins': '00000094: ret',
#          'operation': ['Memory reads 00000020'],
#          'stall': False,
#          'stat': 1,
#          'valA': '18030000',
#          'valE': '1c030000'},
#   'W': { 'bubble': False,
#          'dstE': 15,
#          'dstM': 15,
#          'icode': 13,
#          'ins': '00000093: leave',
#          'operation': [],
#          'stall': False,
#          'stat': 1,
#          'valE': '00000000',
#          'valM': '--------'},
#   'cc': {'OF': False, 'SF': False, 'ZF': True},
#   'control': { 'D_bubble': True,
#                'D_stall': False,
#                'E_bubble': False,
#                'F_stall': True,
#                'M_bubble': False,
#                'W_stall': False},
#   'mem': { '0': '30f40004',
#            '100': 'f2ffffff',
#            '1008': '00040000',
#            '1012': '39000000',
#            '1016': '14000000',
#            '1020': '04000000',
#            '104': 'ff6020a0',
#            '108': '0f30f204',
#            '112': '00000020',
#            '116': '306020a0',
#            '12': '70240000',
#            '120': '0f803a00',
#            '124': '00005023',
#            '132': '6020708d',
#            '136': '00000063',
#            '140': '005035e8',
#            '144': 'ffffffd0',
#            '148': '90000000',
#            '20': '0d000000',
#            '24': 'c0000000',
#            '28': '000b0000',
#            '32': '00a00000',
#            '36': '30f00400',
#            '4': '000030f5',
#            '40': '0000a00f',
#            '44': '30f21400',
#            '48': '0000a02f',
#            '52': '803a0000',
#            '56': '0000a05f',
#            '60': '204530f0',
#            '64': '14000000',
#            '68': '6104a03f',
#            '72': '50350800',
#            '76': '00005005',
#            '792': '20000000',
#            '8': '00040000',
#            '80': '0c000000',
#            '816': '60030000',
#            '820': '7e000000',
#            '824': '24000000',
#            '84': '6200718b',
#            '840': '1c000000',
#            '864': '90030000',
#            '868': '7e000000',
#            '872': '20000000',
#            '876': '01000000',
#            '88': '00000030',
#            '888': '18000000',
#            '912': 'c0030000',
#            '916': '7e000000',
#            '92': 'f2f8ffff',
#            '920': '1c000000',
#            '924': '02000000',
#            '936': '14000000',
#            '96': 'ff602430',
#            '960': 'f0030000',
#            '964': '7e000000',
#            '968': '18000000',
#            '972': '03000000'},
#   'reg': { 'EAX': '00000000',
#            'EBP': '00000330',
#            'EBX': '00000020',
#            'ECX': '00000000',
#            'EDI': '00000000',
#            'EDX': '00000004',
#            'ESI': '00000000',
#            'ESP': '00000318'}}

# %%
pp.pprint(res['53'])
# Out:
# { 'D': { '_dstE': 0,
#          '_dstM': 15,
#          '_srcA': 6,
#          '_srcB': 0,
#          '_valA': '00000000',
#          '_valB': '00000000',
#          'bubble': False,
#          'icode': 6,
#          'ifun': 0,
#          'rA': 6,
#          'rB': 0,
#          'stall': False,
#          'stat': 1,
#          'valC': None,
#          'valP': '63000000'},
#   'E': { '_Cnd': False,
#          '_aluFun': 0,
#          '_dstE': 15,
#          '_set_cc': False,
#          '_valA': '00000000',
#          '_valB': '10000000',
#          '_valE': '10000000',
#          'bubble': False,
#          'dstE': 15,
#          'dstM': 6,
#          'icode': 5,
#          'ifun': 0,
#          'srcA': 15,
#          'srcB': 1,
#          'stall': False,
#          'stat': 1,
#          'valA': '00000000',
#          'valB': '10000000',
#          'valC': '00000000'},
#   'F': { '_icode': 3,
#          '_ifun': 0,
#          '_imem_error': False,
#          '_instr_valid': True,
#          '_need_regid': True,
#          '_need_valC': True,
#          '_pc': '63000000',
#          '_predPC': '69000000',
#          '_rA': 15,
#          '_rB': 3,
#          '_stat': 1,
#          '_valC': '04000000',
#          '_valP': '69000000',
#          'bubble': False,
#          'predPC': '63000000',
#          'stall': True},
#   'M': { 'Cnd': True,
#          '_dmem_error': False,
#          '_mem_addr': None,
#          '_mem_read': False,
#          '_mem_write': False,
#          '_stat': 1,
#          'bubble': False,
#          'dstE': 15,
#          'icode': 7,
#          'ifun': 4,
#          'stall': False,
#          'stat': 1,
#          'valA': '78000000',
#          'valE': '00000000'},
#   'W': { '_Stat': 1,
#          'bubble': False,
#          'dstE': 2,
#          'dstM': 15,
#          'icode': 6,
#          'stall': False,
#          'stat': 1,
#          'valE': '10000000',
#          'valM': '80240000'},
#   'cyc': 53,
#   'mem': { '0': '30f40001',
#            '100': 'f3040000',
#            '104': '00603130',
#            '108': 'f3ffffff',
#            '112': 'ff603274',
#            '116': '5b000000',
#            '12': '80240000',
#            '120': '2054b05f',
#            '124': '90000000',
#            '20': '0d000000',
#            '232': 'f8000000',
#            '236': '3d000000',
#            '24': 'c0000000',
#            '240': '14000000',
#            '244': '04000000',
#            '248': '00010000',
#            '252': '11000000',
#            '28': '000b0000',
#            '32': '00a00000',
#            '36': 'a05f2045',
#            '4': '000030f5',
#            '40': '30f00400',
#            '44': '0000a00f',
#            '48': '30f21400',
#            '52': '0000a02f',
#            '56': '80420000',
#            '60': '002054b0',
#            '64': '5f90a05f',
#            '68': '20455015',
#            '72': '08000000',
#            '76': '50250c00',
#            '8': '00010000',
#            '80': '00006300',
#            '84': '62227378',
#            '88': '00000050',
#            '92': '61000000',
#            '96': '00606030'},
#   'reg': { 'eax': '00000000',
#            'ebp': '000000e8',
#            'ebx': 'ffffffff',
#            'ecx': '00000010',
#            'edi': '00000000',
#            'edx': '00000010',
#            'esi': '00000000',
#            'esp': '000000ec'}}

# %%
def printAt(cc):
    pp.pprint(res[str(cc)]['F'])
    pp.pprint(res[str(cc + 1)]['D'])
    pp.pprint(res[str(cc + 2)]['E'])
    pp.pprint(res[str(cc + 3)]['M'])
    pp.pprint(res[str(cc + 4)]['W'])

# %%
printAt(50)
# Out:
# { '_icode': 7,
#   '_ifun': 4,
#   '_imem_error': False,
#   '_instr_valid': True,
#   '_need_regid': False,
#   '_need_valC': True,
#   '_pc': '73000000',
#   '_predPC': '5b000000',
#   '_rA': 15,
#   '_rB': 15,
#   '_stat': 1,
#   '_valC': '5b000000',
#   '_valP': '78000000',
#   'bubble': False,
#   'predPC': '73000000',
#   'stall': False}
# { '_dstE': 15,
#   '_dstM': 15,
#   '_srcA': 15,
#   '_srcB': 15,
#   '_valA': '78000000',
#   '_valB': '80240000',
#   'bubble': False,
#   'icode': 7,
#   'ifun': 4,
#   'rA': 15,
#   'rB': 15,
#   'stall': False,
#   'stat': 1,
#   'valC': '5b000000',
#   'valP': '78000000'}
# { '_Cnd': True,
#   '_aluFun': 0,
#   '_dstE': 15,
#   '_set_cc': False,
#   '_valA': '00000000',
#   '_valB': '00000000',
#   '_valE': '00000000',
#   'bubble': False,
#   'dstE': 15,
#   'dstM': 15,
#   'icode': 7,
#   'ifun': 4,
#   'srcA': 15,
#   'srcB': 15,
#   'stall': False,
#   'stat': 1,
#   'valA': '78000000',
#   'valB': '80240000',
#   'valC': '5b000000'}
# { 'Cnd': True,
#   '_dmem_error': False,
#   '_mem_addr': None,
#   '_mem_read': False,
#   '_mem_write': False,
#   '_stat': 1,
#   'bubble': False,
#   'dstE': 15,
#   'icode': 7,
#   'ifun': 4,
#   'stall': False,
#   'stat': 1,
#   'valA': '78000000',
#   'valE': '00000000'}
# { '_Stat': 1,
#   'bubble': False,
#   'dstE': 15,
#   'dstM': 15,
#   'icode': 7,
#   'stall': False,
#   'stat': 1,
#   'valE': '00000000',
#   'valM': '80240000'}

# %%
pp.pprint(res['21'])
# Out:
# { 'D': { '_dstE': 0,
#          '_dstM': 15,
#          '_srcA': 6,
#          '_srcB': 0,
#          '_valA': '00000000',
#          '_valB': '00000000',
#          'bubble': False,
#          'icode': 6,
#          'ifun': 0,
#          'rA': 6,
#          'rB': 0,
#          'stall': False,
#          'stat': 1,
#          'valC': None,
#          'valP': '63000000'},
#   'E': { '_Cnd': False,
#          '_aluFun': 0,
#          '_dstE': 15,
#          '_set_cc': False,
#          '_valA': '00000000',
#          '_valB': '00000000',
#          '_valE': '00000000',
#          'bubble': False,
#          'dstE': 15,
#          'dstM': 6,
#          'icode': 5,
#          'ifun': 0,
#          'srcA': 15,
#          'srcB': 1,
#          'stall': False,
#          'stat': 1,
#          'valA': '04000000',
#          'valB': '00000000',
#          'valC': '00000000'},
#   'F': { '_icode': 3,
#          '_ifun': 0,
#          '_imem_error': False,
#          '_instr_valid': True,
#          '_need_regid': True,
#          '_need_valC': True,
#          '_pc': '63000000',
#          '_predPC': '69000000',
#          '_rA': 15,
#          '_rB': 3,
#          '_stat': 1,
#          '_valC': '04000000',
#          '_valP': '69000000',
#          'bubble': False,
#          'predPC': '63000000',
#          'stall': False},
#   'M': { 'Cnd': False,
#          '_dmem_error': False,
#          '_mem_addr': 'e8000000',
#          '_mem_read': True,
#          '_mem_write': False,
#          '_stat': 1,
#          'bubble': False,
#          'dstE': 4,
#          'icode': 11,
#          'ifun': 0,
#          'stall': False,
#          'stat': 1,
#          'valA': 'e8000000',
#          'valE': 'ec000000'},
#   'W': { '_Stat': 1,
#          'bubble': False,
#          'dstE': 15,
#          'dstM': 15,
#          'icode': 1,
#          'stall': False,
#          'stat': 5,
#          'valE': '00000000',
#          'valM': '04000000'},
#   'cyc': 21,
#   'mem': { '0': '30f40001',
#            '100': 'f3040000',
#            '104': '00603130',
#            '108': 'f3ffffff',
#            '112': 'ff603274',
#            '116': '5b000000',
#            '12': '80240000',
#            '120': '2054b05f',
#            '124': '90000000',
#            '20': '0d000000',
#            '232': 'f8000000',
#            '236': '3d000000',
#            '24': 'c0000000',
#            '240': '14000000',
#            '244': '04000000',
#            '248': '00010000',
#            '252': '11000000',
#            '28': '000b0000',
#            '32': '00a00000',
#            '36': 'a05f2045',
#            '4': '000030f5',
#            '40': '30f00400',
#            '44': '0000a00f',
#            '48': '30f21400',
#            '52': '0000a02f',
#            '56': '80420000',
#            '60': '002054b0',
#            '64': '5f90a05f',
#            '68': '20455015',
#            '72': '08000000',
#            '76': '50250c00',
#            '8': '00010000',
#            '80': '00006300',
#            '84': '62227378',
#            '88': '00000050',
#            '92': '61000000',
#            '96': '00606030'},
#   'reg': { 'eax': '00000000',
#            'ebp': '000000e8',
#            'ebx': '00000000',
#            'ecx': '00000000',
#            'edi': '00000000',
#            'edx': '00000014',
#            'esi': '00000000',
#            'esp': '000000e8'}}

# %%
printAt(21)
# Out:
# { '_icode': 3,
#   '_ifun': 0,
#   '_imem_error': False,
#   '_instr_valid': True,
#   '_need_regid': True,
#   '_need_valC': True,
#   '_pc': '63000000',
#   '_predPC': '69000000',
#   '_rA': 15,
#   '_rB': 3,
#   '_stat': 1,
#   '_valC': '04000000',
#   '_valP': '69000000',
#   'bubble': False,
#   'predPC': '63000000',
#   'stall': False}
# { '_dstE': 3,
#   '_dstM': 15,
#   '_srcA': 15,
#   '_srcB': 15,
#   '_valA': '00000000',
#   '_valB': '00000000',
#   'bubble': False,
#   'icode': 3,
#   'ifun': 0,
#   'rA': 15,
#   'rB': 3,
#   'stall': False,
#   'stat': 1,
#   'valC': '04000000',
#   'valP': '69000000'}
# { '_Cnd': False,
#   '_aluFun': 0,
#   '_dstE': 3,
#   '_set_cc': False,
#   '_valA': '04000000',
#   '_valB': '00000000',
#   '_valE': '04000000',
#   'bubble': False,
#   'dstE': 3,
#   'dstM': 15,
#   'icode': 3,
#   'ifun': 0,
#   'srcA': 15,
#   'srcB': 15,
#   'stall': False,
#   'stat': 1,
#   'valA': '00000000',
#   'valB': '00000000',
#   'valC': '04000000'}
# { 'Cnd': False,
#   '_dmem_error': False,
#   '_mem_addr': None,
#   '_mem_read': False,
#   '_mem_write': False,
#   '_stat': 1,
#   'bubble': False,
#   'dstE': 3,
#   'icode': 3,
#   'ifun': 0,
#   'stall': False,
#   'stat': 1,
#   'valA': '00000000',
#   'valE': '04000000'}
# { '_Stat': 1,
#   'bubble': False,
#   'dstE': 3,
#   'dstM': 15,
#   'icode': 3,
#   'stall': False,
#   'stat': 1,
#   'valE': '04000000',
#   'valM': '30f40001'}
